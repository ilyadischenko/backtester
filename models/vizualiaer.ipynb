# %%
from data_manager import DataManager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from data_manager import DataManager
#
# File ~/Documents/Програмирование/backend/backtester/models/data_manager.py:11
#       8 from dataclasses import dataclass
#       9 import io
# ---> 11 from data.config import S3_CONFIG
#      13 # from config import S3_CONFIG, DATA_DIR
#      15 DATA_DIR = Path("../store")
#
# ModuleNotFoundError: No module named 'data'
